# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', parse_dates=['date'])
df.dropna(subset = ['count'], inplace=True)

# %%
def polar_days(row):
    
    if (row.date.year % 4 == 0):
        return (row.date.dayofyear / 366 * 360)
    else:
        return (row.date.dayofyear / 365 * 360)

import numpy as np
df['polar_date'] = df.apply(lambda row: polar_days(row), axis=1)
df['year'] = pd.Categorical(df.date.dt.year)
df = df.sort_values(['year', 'polar_date'])

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# fig = px.scatter_polar(df, r="count", theta="polar_date", color="year", symbol="year", log_r=True,
#                        color_discrete_sequence = px.colors.sequential.Viridis,
#                        range_r=[50, 100000], custom_data=[df.date.dt.strftime('%Y-%m-%d'), 'name'])
# # months = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
# #           'August', 'September', 'October', 'November', 'December']

# months = ['Январь', 'Февраль', 'Март', 'Апрель', 'Май', 'Июнь', 'Июль',
#           'Август', 'Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь']

# fig.update_layout(
#     template=None,
#     polar = dict(
#         angularaxis = dict(tickvals=[(a*30) for a in range(0, 12)], ticktext=months), 
#         radialaxis = dict(tickvals=[100, 1000, 10000, 50000]),),
#     legend_title='<b> Год </b>'
    

# )
# fig.update_traces(
#    hovertemplate='<b>%{customdata[1]}</b><br>Дата: %{customdata[0]}<br>Численность: %{r}',
# )
# fig.show()
# Out:
# <div>
#
#
#             <div id="5d09389e-dc34-4ada-b89d-0401531ce284" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d09389e-dc34-4ada-b89d-0401531ce284")) {
#                     Plotly.newPlot(
#                         '5d09389e-dc34-4ada-b89d-0401531ce284',
#                         [{"customdata": [["2013-01-13", "\u0428\u0435\u0441\u0442\u0432\u0438\u0435 \u043f\u0440\u043e\u0442\u0438\u0432 \u0437\u0430\u043a\u043e\u043d\u0430 \u043f\u043e\u0434\u043b\u0435\u0446\u043e\u0432"], ["2013-03-02", "\u041c\u0430\u0440\u0448 \u0432 \u0437\u0430\u0449\u0438\u0442\u0443 \u0434\u0435\u0442\u0435\u0439"], ["2013-05-06", "\u0417\u0430 \u0441\u0432\u043e\u0431\u043e\u0434\u0443!"], ["2013-06-12", "\u041c\u0430\u0440\u0448 \u043f\u0440\u043e\u0442\u0438\u0432 \u043f\u0430\u043b\u0430\u0447\u0435\u0439"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{customdata[1]}</b><br>\u0414\u0430\u0442\u0430: %{customdata[0]}<br>\u0427\u0438\u0441\u043b\u0435\u043d\u043d\u043e\u0441\u0442\u044c: %{r}", "legendgroup": "2013", "marker": {"color": "#440154", "symbol": "circle"}, "mode": "markers", "name": "2013", "r": [24000.0, 13000.0, 27500.0, 9200.0], "showlegend": true, "subplot": "polar", "theta": [12.821917808219178, 60.16438356164384, 124.27397260273973, 160.76712328767124], "type": "scatterpolar"}, {"customdata": [["2014-03-15", "\u041c\u0430\u0440\u0448 \u043c\u0438\u0440\u0430"], ["2014-09-21", "\u041c\u0430\u0440\u0448 \u043c\u0438\u0440\u0430 - 2"], ["2014-11-02", "\u041e\u0441\u0442\u0430\u043d\u043e\u0432\u0438\u0442\u044c \u0440\u0430\u0437\u0432\u0430\u043b \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u044b \u041c\u043e\u0441\u043a\u0432\u044b"], ["2014-11-04", "\u0420\u0443\u0441\u0441\u043a\u0438\u0439 \u043c\u0430\u0440\u0448"], ["2014-11-30", "#\u041c\u0438\u0442\u0438\u043d\u0433\u0412\u0440\u0430\u0447\u0435\u0439"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{customdata[1]}</b><br>\u0414\u0430\u0442\u0430: %{customdata[0]}<br>\u0427\u0438\u0441\u043b\u0435\u043d\u043d\u043e\u0441\u0442\u044c: %{r}", "legendgroup": "2014", "marker": {"color": "#482878", "symbol": "diamond"}, "mode": "markers", "name": "2014", "r": [22800.0, 26100.0, 6600.0, 2300.0, 5600.0], "showlegend": true, "subplot": "polar", "theta": [72.98630136986301, 260.3835616438356, 301.8082191780822, 303.7808219178082, 329.4246575342466], "type": "scatterpolar"}, {"customdata": [["2015-03-01", "#\u041c\u0430\u0440\u0448\u041f\u0430\u043c\u044f\u0442\u0438"], ["2015-06-06", "#\u041c\u0438\u0442\u0438\u043d\u0433\u0417\u0430\u041d\u0430\u0443\u043a\u0443"], ["2015-09-20", "#\u0417\u0430\u0441\u043c\u0435\u043d\u044f\u0435\u043c\u043e\u0441\u0442\u044c\u0432\u043b\u0430\u0441\u0442\u0438"], ["2015-10-17", "\u041d\u0435\u0442 \u0432\u043e\u0439\u043d\u0435"], ["2015-10-27", "\u041c\u0438\u0442\u0438\u043d\u0433 \u043f\u0440\u043e\u0442\u0438\u0432 \u0440\u0430\u0441\u0448\u0438\u0440\u0435\u043d\u0438\u044f \u043f\u043b\u0430\u0442\u043d\u044b\u0445 \u043f\u0430\u0440\u043a\u043e\u0432\u043e\u041c"], ["2015-10-31", "\u041c\u0438\u0442\u0438\u043d\u0433 \u0430\u0432\u0442\u043e\u043c\u043e\u0431\u0438\u043b\u0438\u0441\u0442\u043e\u0432 \u0432 \u0440\u0430\u0439\u043e\u043d\u0435 #\u041e\u0442\u0440\u0430\u0434\u043d\u043e\u0435"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{customdata[1]}</b><br>\u0414\u0430\u0442\u0430: %{customdata[0]}<br>\u0427\u0438\u0441\u043b\u0435\u043d\u043d\u043e\u0441\u0442\u044c: %{r}", "legendgroup": "2015", "marker": {"color": "#3e4989", "symbol": "square"}, "mode": "markers", "name": "2015", "r": [51600.0, 3500.0, 7100.0, 420.0, 925.0, 415.0], "showlegend": true, "subplot": "polar", "theta": [59.17808219178082, 154.84931506849315, 259.3972602739726, 286.027397260274, 295.8904109589041, 299.83561643835617], "type": "scatterpolar"}, {"customdata": [["2016-01-23", "\u041c\u0438\u0442\u0438\u043d\u0433 \u043f\u0440\u043e\u0442\u0438\u0432 \u0440\u0435\u043f\u0440\u0435\u0441\u0441\u0438\u0439"], ["2016-02-27", "#\u041c\u0430\u0440\u0448\u041f\u0430\u043c\u044f\u0442\u0438"], ["2016-08-09", "#\u0412\u0417\u0430\u0449\u0438\u0442\u0443\u0418\u043d\u0442\u0435\u0440\u043d\u0435\u0442\u0430"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{customdata[1]}</b><br> ...

# %%
fig = px.scatter_polar(df, r="year", theta="polar_date", color=np.sqrt(df['count']), size=np.sqrt(df['count']), #symbol="year", log_r=True,
                       color_continuous_scale = px.colors.sequential.Viridis[2:6], 
                       title='Данные Белого Счетчика по протестным акциям в Москве',
                       range_r=[2011, 2020], custom_data=[df.date.dt.strftime('%Y-%m-%d'), 'name', 'count'])
# months = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
#           'August', 'September', 'October', 'November', 'December']

months = ['Январь', 'Февраль', 'Март', 'Апрель', 'Май', 'Июнь', 'Июль',
          'Август', 'Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь']

fig.update_layout(
    template=None,
    
    font=dict(
#         family="Courier New, monospace",
        size=14,
#         color="#7f7f7f"
    ),
    polar = dict(
        angularaxis = dict(tickvals=[(a*30) for a in range(0, 12)], ticktext=months), 
        radialaxis = dict(tickvals=[2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
                          angle = 90,
                          tickangle = 90 # so that tick labels are not upside down
                         ),
    ),
    coloraxis_colorbar=dict(
        title="Численность",
#         thicknessmode="pixels", thickness=50,
#         lenmode="pixels", len=200,
        yanchor="top", y=1,
        ticks="outside",
    tickvals=np.sqrt([1000, 10000, 25000, 50000]),
    ticktext=['1 тыс.', '10 тыс.', '25  тыс.', '50 тыс.'],
    

)
)
fig.update_traces(
   hovertemplate='<b>%{customdata[1]}</b><br>Дата: %{customdata[0]}<br>Численность: %{customdata[2]}',
)
fig.show()
# Out:
# <div>
#
#
#             <div id="2e1f448b-2efa-430f-b82d-273b6877fd0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e1f448b-2efa-430f-b82d-273b6877fd0b")) {
#                     Plotly.newPlot(
#                         '2e1f448b-2efa-430f-b82d-273b6877fd0b',
#                         [{"customdata": [["2013-01-13", "\u0428\u0435\u0441\u0442\u0432\u0438\u0435 \u043f\u0440\u043e\u0442\u0438\u0432 \u0437\u0430\u043a\u043e\u043d\u0430 \u043f\u043e\u0434\u043b\u0435\u0446\u043e\u0432", 24000.0], ["2013-03-02", "\u041c\u0430\u0440\u0448 \u0432 \u0437\u0430\u0449\u0438\u0442\u0443 \u0434\u0435\u0442\u0435\u0439", 13000.0], ["2013-05-06", "\u0417\u0430 \u0441\u0432\u043e\u0431\u043e\u0434\u0443!", 27500.0], ["2013-06-12", "\u041c\u0430\u0440\u0448 \u043f\u0440\u043e\u0442\u0438\u0432 \u043f\u0430\u043b\u0430\u0447\u0435\u0439", 9200.0], ["2014-03-15", "\u041c\u0430\u0440\u0448 \u043c\u0438\u0440\u0430", 22800.0], ["2014-09-21", "\u041c\u0430\u0440\u0448 \u043c\u0438\u0440\u0430 - 2", 26100.0], ["2014-11-02", "\u041e\u0441\u0442\u0430\u043d\u043e\u0432\u0438\u0442\u044c \u0440\u0430\u0437\u0432\u0430\u043b \u043c\u0435\u0434\u0438\u0446\u0438\u043d\u044b \u041c\u043e\u0441\u043a\u0432\u044b", 6600.0], ["2014-11-04", "\u0420\u0443\u0441\u0441\u043a\u0438\u0439 \u043c\u0430\u0440\u0448", 2300.0], ["2014-11-30", "#\u041c\u0438\u0442\u0438\u043d\u0433\u0412\u0440\u0430\u0447\u0435\u0439", 5600.0], ["2015-03-01", "#\u041c\u0430\u0440\u0448\u041f\u0430\u043c\u044f\u0442\u0438", 51600.0], ["2015-06-06", "#\u041c\u0438\u0442\u0438\u043d\u0433\u0417\u0430\u041d\u0430\u0443\u043a\u0443", 3500.0], ["2015-09-20", "#\u0417\u0430\u0441\u043c\u0435\u043d\u044f\u0435\u043c\u043e\u0441\u0442\u044c\u0432\u043b\u0430\u0441\u0442\u0438", 7100.0], ["2015-10-17", "\u041d\u0435\u0442 \u0432\u043e\u0439\u043d\u0435", 420.0], ["2015-10-27", "\u041c\u0438\u0442\u0438\u043d\u0433 \u043f\u0440\u043e\u0442\u0438\u0432 \u0440\u0430\u0441\u0448\u0438\u0440\u0435\u043d\u0438\u044f \u043f\u043b\u0430\u0442\u043d\u044b\u0445 \u043f\u0430\u0440\u043a\u043e\u0432\u043e\u041c", 925.0], ["2015-10-31", "\u041c\u0438\u0442\u0438\u043d\u0433 \u0430\u0432\u0442\u043e\u043c\u043e\u0431\u0438\u043b\u0438\u0441\u0442\u043e\u0432 \u0432 \u0440\u0430\u0439\u043e\u043d\u0435 #\u041e\u0442\u0440\u0430\u0434\u043d\u043e\u0435", 415.0], ["2016-01-23", "\u041c\u0438\u0442\u0438\u043d\u0433 \u043f\u0440\u043e\u0442\u0438\u0432 \u0440\u0435\u043f\u0440\u0435\u0441\u0441\u0438\u0439", 680.0], ["2016-02-27", "#\u041c\u0430\u0440\u0448\u041f\u0430\u043c\u044f\u0442\u0438", 24200.0], ["2016-08-09", "#\u0412\u0417\u0430\u0449\u0438\u0442\u0443\u0418\u043d\u0442\u0435\u0440\u043d\u0435\u0442\u0430", 2640.0], ["2017-01-29", "#\u0412_\u0437\u0430\u0449\u0438\u0442\u0443_\u0442\u0440\u043e\u043b\u043b\u0435\u0439\u0431\u0443\u0441\u0430", 960.0], ["2017-02-26", "#\u041c\u0430\u0440\u0448\u041d\u0435\u043c\u0446\u043e\u0432\u0430", 15200.0], ["2017-04-08", "#\u041d\u043e\u0432\u0430\u044f\u041e\u043f\u043f\u043e\u0437\u0438\u0446\u0438\u044f", 590.0], ["2017-04-08", "\u041c\u0438\u0442\u0438\u043d\u0433 #\u041a\u041f\u0420\u0424", 1600.0], ["2017-05-06", "#6\u043c\u0430\u044f", 2800.0], ["2017-05-14", "#\u043d\u0435\u0442\u0440\u0435\u043d\u043e\u0432\u0430\u0446\u0438\u0438", 20200.0], ["2017-05-28", "#\u041f\u0440\u043e\u0442\u0438\u0432\u0417\u0430\u0441\u0442\u0440\u043e\u0439\u043a\u0438", 4900.0], ["2018-02-25", "#\u041c\u0430\u0440\u0448\u041d\u0435\u043c\u0446\u043e\u0432\u0430", 7600.0], ["2018-04-30", "\u0417\u0430 #Telegram", 12300.0], ["2018-05-13", "#\u0417\u0430\u0418\u043d\u0442\u0435\u0440\u043d\u0435\u0442", 2400.0], ["2018-07-28", "#\u041f\u0440\u043e\u0442\u0438\u0432\u041f\u0435\u043d\u0441\u0438\u043e\u043d\u043d\u043e\u0439\u0420\u0435\u0444\u043e\u0440\u043c\u044b", 12000.0], ["2018-07-29", "#\u041f\u0440\u043e\u0442\u0438\u0432\u0413\u0440\u0430\u0431\u0435\u0436\u0430", 6200.0], ["2018-09-02", "#\u041f\u0440\u043e\u0442\u0438\u0432\u041f\u0435\u043d\u0441\u0438\u043e\u043d\u043d\u043e\u0439\u0420\u0435\u0444\u043e\u0440\u043c\u044b", 8900.0], ["2018-09-04", "\u0412 \u0437\u0430\u0449\u0438\u0442\u0443 \u0412\u043e\u0440\u043e\u043d\u0446\u043e\u0432\u0441\u043a\u043e\u0433\u043e \u043f\u0430\u0440\u043a\u0430", 120.0], ["2018-12- ...
